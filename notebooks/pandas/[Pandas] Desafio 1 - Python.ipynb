# %%
import pandas
import requests

from datetime import date

# %%
response = requests.get('https://pogoapi.net/api/v1/fast_moves.json')

today = date.today().strftime('%d/%m/%Y')

dataframe = pandas.json_normalize(response.json())

dataframe['id'] = dataframe['move_id']
dataframe['total_damage'] = dataframe.power * dataframe.duration
dataframe['created_at'] = today

dataframe = dataframe[['id',
                       'stamina_loss_scaler',
                       'name',
                       'power',
                       'duration',
                       'energy_delta',
                       'type',
                       'total_damage',
                       'created_at',
                       'move_id']]

del dataframe['move_id']

dataframe.to_csv('pokemon.csv', encoding='utf-8', index=False)

# %%
dataframe.head()
# Out:
#     id  stamina_loss_scaler           name  power  duration  energy_delta  \
# 0  200                 0.01    Fury Cutter      3       400             6
# 1  201                 0.01       Bug Bite      5       500             6
# 2  202                 0.01           Bite      6       500             4
# 3  203                 0.01   Sucker Punch      7       700             8
# 4  204                 0.01  Dragon Breath      6       500             4
#
#      type  total_damage  created_at
# 0     Bug          1200  04/09/2020
# 1     Bug          2500  04/09/2020
# 2    Dark          3000  04/09/2020
# 3    Dark          4900  04/09/2020
# 4  Dragon          3000  04/09/2020
